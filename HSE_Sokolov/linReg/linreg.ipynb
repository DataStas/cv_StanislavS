# %% [markdown]
# Введение
# Линейные методы хорошо подходят для работы с разреженными данными — к таковым относятся, например, тексты. Это можно объяснить высокой скоростью обучения и небольшим количеством параметров, благодаря чему удается избежать переобучения.
#
# Линейная регрессия имеет несколько разновидностей в зависимости от того, какой регуляризатор используется. Мы будем работать с гребневой регрессией, где применяется квадратичный, или L2-регуляризатор.
#
# Реализация в Scikit-Learn
# Для извлечения TF-IDF-признаков из текстов воспользуйтесь классом sklearn.feature_extraction.text.TfidfVectorizer.
#
# Для предсказания целевой переменной мы будем использовать гребневую регрессию, которая реализована в классе sklearn.linear_model.Ridge.
#
# Обратите внимание, что признаки LocationNormalized и ContractTime являются строковыми, и поэтому с ними нельзя работать напрямую. Такие нечисловые признаки с неупорядоченными значениями называют категориальными или номинальными. Типичный подход к их обработке — кодирование категориального признака с m возможными значениями с помощью m бинарных признаков. Каждый бинарный признак соответствует одному из возможных значений категориального признака и является индикатором того, что на данном объекте он принимает данное значение. Данный подход иногда называют one-hot-кодированием. Воспользуйтесь им, чтобы перекодировать признаки LocationNormalized и ContractTime. Он уже реализован в классе sklearn.feature_extraction.DictVectorizer. Пример использования:

# %%
from sklearn.feature_extraction import DictVectorizer
enc = DictVectorizer()
X_train_categ = enc.fit_transform(data_train[['LocationNormalized', 'ContractTime']].to_dict('records'))
X_test_categ = enc.transform(data_test[['LocationNormalized', 'ContractTime']].to_dict('records'))

# %% [markdown]
# Вам понадобится производить замену пропущенных значений на специальные строковые величины (например, 'nan'). Для этого подходит следующий код:

# %%
data_train['LocationNormalized'].fillna('nan', inplace=True)
data_train['ContractTime'].fillna('nan', inplace=True)

# %% [markdown]
# **1. Загрузите данные об описаниях вакансий и соответствующих годовых зарплатах из файла salary-train.csv (либо его заархивированную версию salary-train.zip).**

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Ridge

# %%
train = pd.read_csv('./salary-train.csv')
test = pd.read_csv('./salary-test-mini.csv')

# %% [markdown]
# **2. Проведите предобработку:**
# + Приведите тексты к нижнему регистру (text.lower()).
#
# + Замените все, кроме букв и цифр, на пробелы — это облегчит дальнейшее разделение текста на слова. Для такой замены в строке text подходит следующий вызов: re.sub('[^a-zA-Z0-9]', ' ', text). Также можно воспользоваться методом replace у DataFrame, чтобы сразу преобразовать все тексты:
# train['FullDescription'] = train['FullDescription'].replace('[^a-zA-Z0-9]', ' ', regex = True)
#
# + Примените TfidfVectorizer для преобразования текстов в векторы признаков. Оставьте только те слова, которые встречаются хотя бы в 5 объектах (параметр min_df у TfidfVectorizer).
#
# + Замените пропуски в столбцах LocationNormalized и ContractTime на специальную строку 'nan'. Код для этого был приведен выше.
#
# + Примените DictVectorizer для получения one-hot-кодирования признаков LocationNormalized и ContractTime.
#
# + Объедините все полученные признаки в одну матрицу "объекты-признаки". Обратите внимание, что матрицы для текстов и категориальных признаков являются разреженными. Для объединения их столбцов нужно воспользоваться функцией scipy.sparse.hstack.

# %%
# можно использовать lowercase=True у TfidfVectorizer
train['FullDescription'] = train['FullDescription'].str.lower()
test['FullDescription'] = test['FullDescription'].str.lower()

# %%
train['FullDescription'] = train['FullDescription'].replace('[^a-zA-Z0-9]', ' ', regex = True)
test['FullDescription'] = test['FullDescription'].replace('[^a-zA-Z0-9]', ' ', regex = True)

# %%
tf_idf = TfidfVectorizer(min_df=5, lowercase=True)
X_train_description = tf_idf.fit_transform(train['FullDescription'])

# %%
train['LocationNormalized'].fillna('nan', inplace=True)
train['ContractTime'].fillna('nan', inplace=True)

# %%
enc = DictVectorizer()
X_train_features = enc.fit_transform(train[['LocationNormalized', 'ContractTime']].to_dict('records'))

# %%
data_new_train = hstack([X_train_features, X_train_description])

# %%
X_train_features.shape
# Out:
# (60000, 1766)

# %%
len(tf_idf.vocabulary_)
# Out:
# 22861

# %%
enc.feature_names_
# Out:
# ['ContractTime=contract',
#  'ContractTime=nan',
#  'ContractTime=permanent',
#  'LocationNormalized=Abbots Langley',
#  'LocationNormalized=Aberaeron',
#  'LocationNormalized=Aberdare',
#  'LocationNormalized=Aberdeen',
#  'LocationNormalized=Aberdeenshire',
#  'LocationNormalized=Abergele',
#  'LocationNormalized=Abertillery',
#  'LocationNormalized=Aberystwyth',
#  'LocationNormalized=Abingdon',
#  'LocationNormalized=Aboyne',
#  'LocationNormalized=Accrington',
#  'LocationNormalized=Acton',
#  'LocationNormalized=Acton Gate',
#  'LocationNormalized=Addlestone',
#  'LocationNormalized=Adlington',
#  'LocationNormalized=Aintree',
#  'LocationNormalized=Airdrie',
#  'LocationNormalized=Alcester',
#  'LocationNormalized=Aldeburgh',
#  'LocationNormalized=Alderley',
#  'LocationNormalized=Alderley Edge',
#  'LocationNormalized=Aldershot',
#  'LocationNormalized=Aldford',
#  'LocationNormalized=Aldham Tye',
#  'LocationNormalized=Alexandria',
#  'LocationNormalized=Alford',
#  'LocationNormalized=Alfreton',
#  'LocationNormalized=Alfriston',
#  'LocationNormalized=All Saints',
#  'LocationNormalized=Alloa',
#  'LocationNormalized=Alnwick',
#  'LocationNormalized=Alresford',
#  'LocationNormalized=Alston',
#  'LocationNormalized=Altnagelvin',
#  'LocationNormalized=Alton',
#  'LocationNormalized=Altrincham',
#  'LocationNormalized=Alvaston',
#  'LocationNormalized=Ambleside',
#  'LocationNormalized=Amersham',
#  'LocationNormalized=Amesbury',
#  'LocationNormalized=Ammanford',
#  'LocationNormalized=Andover',
#  'LocationNormalized=Angus',
#  'LocationNormalized=Annan',
#  'LocationNormalized=Anstruther',
#  'LocationNormalized=Antony Estate',
#  'LocationNormalized=Antrim',
#  'LocationNormalized=Arbroath',
#  'LocationNormalized=Ardrossan',
#  'LocationNormalized=Argyll & Bute',
#  'LocationNormalized=Armagh',
#  'LocationNormalized=Arundel',
#  'LocationNormalized=Ascot',
#  'LocationNormalized=Ash Green',
#  'LocationNormalized=Ashbourne',
#  'LocationNormalized=Ashby-De-La-Zouch',
#  'LocationNormalized=Ashford',
#  'LocationNormalized=Ashington',
#  'LocationNormalized=Ashtead',
#  'LocationNormalized=Ashton-Under-Lyne',
#  'LocationNormalized=Askham Bryan',
#  'LocationNormalized=Atherstone',
#  'LocationNormalized=Atherton',
#  'LocationNormalized=Attleborough',
#  'LocationNormalized=Avon',
#  'LocationNormalized=Axbridge',
#  'LocationNormalized=Axminster',
#  'LocationNormalized=Aycliffe',
#  'LocationNormalized=Aylesbury',
#  'LocationNormalized=Aylesford',
#  'LocationNormalized=Ayr',
#  'LocationNormalized=Ayr Central',
#  'LocationNormalized=Badminton',
#  'LocationNormalized=Bagshot',
#  'LocationNormalized=Bakewell',
#  'LocationNormalized=Baldock',
#  'LocationNormalized=Balham',
#  'LocationNormalized=Ballycastle',
#  'LocationNormalized=Ballymena',
#  'LocationNormalized=Ballymoney',
#  'LocationNormalized=Ballynahinch',
#  'LocationNormalized=Bampton',
#  'LocationNormalized=Banbury',
#  'LocationNormalized=Banchory',
#  'LocationNormalized=Bangor',
#  'LocationNormalized=Banstead',
#  'LocationNormalized=Bar Hill',
#  'LocationNormalized=Bargoed',
#  'LocationNormalized=Barking',
#  'LocationNormalized=Barnet',
#  'LocationNormalized=Barnoldswick',
#  'LocationNormalized=Barnsley',
#  'LocationNormalized=Barnstaple',
#  'LocationNormalized=Barrow Upon Soar',
#  'LocationNormalized=Barrow-In-Furness',
#  'LocationNormalized=Barrow-Upon-Humber',
#  'LocationNormalized=Barry',
#  'LocationNormalized=Barton-Upon-Humber',
#  'LocationNormalized=Basildon',
#  'LocationNormalized=Basingstoke',
#  'LocationNormalized=Bassaleg',
#  'LocationNormalized=Bath',
#  'LocationNormalized=Bathgate',
#  'LocationNormalized=Batley',
#  'LocationNormalized=Battersea',
#  'LocationNormalized=Battle',
#  'LocationNormalized=Beaconsfield',
#  'LocationNormalized=Beaworthy',
#  'LocationNormalized=Beccles',
#  'LocationNormalized=Beckenham',
#  'LocationNormalized=Beckton',
#  'LocationNormalized=Bedale',
#  'LocationNormalized=Bedfont',
#  'LocationNormalized=Bedford',
#  'LocationNormalized=Bedfordshire',
#  'LocationNormalized=Bedworth',
#  'LocationNormalized=Beeston',
#  'LocationNormalized=Belfast',
#  'LocationNormalized=Belford',
#  'LocationNormalized=Belle Isle',
#  'LocationNormalized=Bellshill',
#  'LocationNormalized=Belmont',
#  'LocationNormalized=Belper',
#  'LocationNormalized=Belvedere',
#  'LocationNormalized=Benfleet',
#  'LocationNormalized=Benmore',
#  'LocationNormalized=Bensham',
#  'LocationNormalized=Berkeley',
#  'LocationNormalized=Berkhamsted',
#  'LocationNormalized=Berkshire',
#  'LocationNormalized=Berrycroft',
#  'LocationNormalized=Berwick-Upon-Tweed',
#  'LocationNormalized=Berwyn',
#  'LocationNormalized=Betchworth',
#  'LocationNormalized=Bethnal Green',
#  'LocationNormalized=Beverley',
#  'LocationNormalized=Bewdley',
#  'LocationNormalized=Bexhill-On-Sea',
#  'LocationNormalized=Bexley',
#  'LocationNormalized=Bexleyheath',
#  'LocationNormalized=Bicester',
#  'LocationNormalized=Biddulph',
#  'LocationNormalized=Bideford',
#  'LocationNormalized=Biggleswade',
#  'LocationNormalized=Billericay',
#  'LocationNormalized=Billingham',
#  'LocationNormalized=Billingshurst',
#  'LocationNormalized=Bilston',
#  'LocationNormalized=Bingley',
#  'LocationNormalized=Bircham Newton',
#  'LocationNormalized=Birchwood',
#  'LocationNormalized=Birkenhead',
#  'LocationNormalized=Birmingham',
#  'LocationNormalized=Birmingham International Airport',
#  'LocationNormalized=Bishop Auckland',
#  "LocationNormalized=Bishop's Stortford",
#  'LocationNormalized=Bishopbriggs',
#  'LocationNormalized=Bishops Castle',
#  'LocationNormalized=Blaby',
#  'LocationNormalized=Blackburn',
#  'LocationNormalized=Blackheath',
#  'LocationNormalized=Blackpool',
#  'LocationNormalized=Blackpool Airport',
#  'LocationNormalized=Blackwood',
#  'LocationNormalized=Blaenau Gwent',
#  'LocationNormalized=Blairgowrie',
#  'LocationNormalized=Blandford Forum',
#  'LocationNormalized=Blantyre',
#  'LocationNormalized=Blaydon-On-Tyne',
#  'LocationNormalized=Bloomsbury',
#  'LocationNormalized=Bloxwich',
#  'LocationNormalized=Bluewater',
#  'LocationNormalized=Blyth',
#  'LocationNormalized=Bodmin',
#  'LocationNormalized=Bognor Regis',
#  'LocationNormalized=Boldon Colliery',
#  'LocationNormalized=Bolton',
#  'LocationNormalized=Bolton Le Sands',
#  'LocationNormalized=Bonnybridge',
#  'LocationNormalized=Bonnyrigg',
#  'LocationNormalized=Bootle',
#  'LocationNormalized=Borders',
#  'LocationNormalized=Bordon',
#  'LocationNormalized=Borehamwood',
#  'LocationNormalized=Boston',
#  'LocationNormalized=Botley',
#  'LocationNormalized=Bourne',
#  'LocationNormalized=Bourne End',
#  'LocationNormalized=Bournemouth',
#  'LocationNormalized=Bournemouth International Airport',
#  'LocationNormalized=Bourton-On-The-Water',
#  'LocationNormalized=Bovington',
#  'LocationNormalized=Bow',
#  'LocationNormalized=Bracebridge',
#  'LocationNormalized=Brackley',
#  'LocationNormalized=Bracknell',
#  'LocationNormalized=Bradford',
#  'LocationNormalized=Bradford-On-Avon',
#  'LocationNormalized=Bradley Cross',
#  'LocationNormalized=Bradley Stoke',
#  'LocationNormalized=Bradshaw',
#  'LocationNormalized=Braintree',
#  'LocationNormalized=Bramhope',
#  'LocationNormalized=Bramley',
#  'LocationNormalized=Brandon',
#  'LocationNormalized=Branksome',
#  'LocationNormalized=Braunton',
#  'LocationNormalized=Brecon',
#  'LocationNormalized=Brent Cross',
#  'LocationNormalized=Brentford',
#  'LocationNormalized=Brentor',
#  'LocationNormalized=Brentwood',
#  'LocationNormalized=Bridgend',
#  'LocationNormalized=Bridgnorth',
#  'LocationNormalized=Bridgwater',
#  'LocationNormalized=Bridlington',
#  'LocationNormalized=Bridport',
#  'LocationNormalized=Brierley Hill',
#  'LocationNormalized=Brighouse',
#  'LocationNormalized=Brightlingsea',
#  'LocationNormalized=Brighton',
#  'LocationNormalized=Bristol',
#  'LocationNormalized=Brixham',
#  'LocationNormalized=Brixton',
#  'LocationNormalized=Brixworth',
#  'LocationNormalized=Broadfield',
#  'LocationNormalized=Broadgate',
#  'LocationNormalized=Broadstairs',
#  'LocationNormalized=Broadway',
#  'LocationNormalized=Brockenhurst',
#  'LocationNormalized=Brockley',
#  'LocationNormalized=Bromley',
#  'LocationNormalized=Brompton',
#  'LocationNormalized=Bromsgrove',
#  'LocationNormalized=Bromyard',
#  'LocationNormalized=Brooklands',
#  'LocationNormalized=Broom',
#  'LocationNormalized=Broseley',
#  'LocationNormalized=Brough',
#  'LocationNormalized=Broughton',
#  'LocationNormalized=Broxbourne',
#  'LocationNormalized=Broxburn',
#  'LocationNormalized=Bruntingthorpe',
#  'LocationNormalized=Bruton',
#  'LocationNormalized=Buckhurst Hill',
#  'LocationNormalized=Buckingham',
#  'LocationNormalized=Buckinghamshire',
#  'LocationNormalized=Buckley',
#  'LocationNormalized=Bude',
#  'LocationNormalized=Builth Wells',
#  'LocationNormalized=Buntingford',
#  'LocationNormalized=Burford',
#  'LocationNormalized=Burgess Hill',
#  'LocationNormalized=Burleydam',
#  'LocationNormalized=Burn Bridge',
#  'LocationNormalized=Burnham-On-Crouch',
#  'LocationNormalized=Burnley',
#  'LocationNormalized=Burntwood',
#  'LocationNormalized=Burton',
#  'LocationNormalized=Burton-On-Trent',
#  'LocationNormalized=Burwell',
#  'LocationNormalized=Bury',
#  'LocationNormalized=Bury St. Edmunds',
#  'LocationNormalized=Bushey',
#  'LocationNormalized=Buxton',
#  'LocationNormalized=Byfleet',
#  'LocationNormalized=Caernarfon',
#  'LocationNormalized=Caerphilly',
#  'LocationNormalized=Cairndow',
#  'LocationNormalized=Calcot',
#  'LocationNormalized=Caldicot',
#  'LocationNormalized=Callington',
#  'LocationNormalized=Calne',
#  'LocationNormalized=Calstock',
#  'LocationNormalized=Camberley',
#  'LocationNormalized=Camborne',
#  'LocationNormalized=Cambridge',
#  'LocationNormalized=Cambridgeshire',
#  'LocationNormalized=Camden',
#  'LocationNormalized=Camden Town',
#  'LocationNormalized=Camperdown',
#  'LocationNormalized=Canary Wharf',
#  'LocationNormalized=Cannock',
#  'LocationNormalized=Canterbury',
#  'LocationNormalized=Canvey Island',
#  'LocationNormalized=Canwick',
#  'LocationNormalized=Cardiff',
#  'LocationNormalized=Cardigan',
#  'LocationNormalized=Carleton',
#  'LocationNormalized=Carlisle',
#  'LocationNormalized=Carluke',
#  'LocationNormalized=Carmarthen',
#  'LocationNormalized=Carmarthenshire',
#  'LocationNormalized=Carnforth',
#  'LocationNormalized=Carrington',
#  'LocationNormalized=Carryduff',
#  'LocationNormalized=Carterton',
#  'LocationNormalized=Castle Cary',
#  'LocationNormalized=Castle Donington',
#  'LocationNormalized=Castle Douglas',
#  'LocationNormalized=Castleford',
#  'LocationNormalized=Castlereagh',
#  'LocationNormalized=Caterham',
#  'LocationNormalized=Catford',
#  'LocationNormalized=Catterick',
#  'LocationNormalized=Catterick Garrison',
#  'LocationNormalized=Central London',
#  'LocationNormalized=Ceredigion',
#  'LocationNormalized=Chadbury',
#  'LocationNormalized=Chadderton',
#  'LocationNormalized=Chalfont St. Giles',
#  'LocationNormalized=Chalfont St. Peter',
#  'LocationNormalized=Chalk Farm',
#  'LocationNormalized=Chalvey',
#  "LocationNormalized=Chandler's Ford",
#  'LocationNormalized=Chandlers Cross',
#  'LocationNormalized=Channel Islands',
#  'LocationNormalized=Chantry',
#  'LocationNormalized=Chard',
#  'LocationNormalized=Charlton',
#  'LocationNormalized=Chatham',
#  'LocationNormalized=Chatteris',
#  'LocationNormalized=Cheadle',
#  'LocationNormalized=Cheadle Hulme',
#  'LocationNormalized=Cheam',
#  'LocationNormalized=Chelmsford',
#  'LocationNormalized=Chelsea',
#  'LocationNormalized=Cheltenham',
#  'LocationNormalized=Cheltenham Trade Park',
#  'LocationNormalized=Chepstow',
#  'LocationNormalized=Chertsey',
#  'LocationNormalized=Chesham',
#  'LocationNormalized=Cheshire',
#  'LocationNormalized=Cheshunt',
#  'LocationNormalized=Chessington',
#  'LocationNormalized=Chester',
#  'LocationNormalized=Chester Le Street',
#  'LocationNormalized=Chesterfield',
#  'LocationNormalized=Chesterton',
#  'LocationNormalized=Chichester',
#  'LocationNormalized=Chigwell',
#  'LocationNormalized=Chilton',
#  'LocationNormalized=Chingford',
#  'LocationNormalized=Chippenham',
#  'LocationNormalized=Chipping Campden',
#  'LocationNormalized=Chipping Norton',
#  'LocationNormalized=Chipping Sodbury',
#  'LocationNormalized=Chobham',
#  'LocationNormalized=Choppington',
#  'LocationNormalized=Chorley',
#  'LocationNormalized=Christchurch',
#  'LocationNormalized=Christleton',
#  'LocationNormalized=Churchbridge',
#  'LocationNormalized=Churwell',
#  'LocationNormalized=Cirencester',
#  'LocationNormalized=City',
#  'LocationNormalized=Clackmannan',
#  'LocationNormalized=Clackmannanshire',
#  'LocationNormalized=Clacton-On-Sea',
#  'LocationNormalized=Clapham',
#  'LocationNormalized=Clapham Junction',
#  'LocationNormalized=Clarbeston Road',
#  'LocationNormalized=Claydon',
#  'LocationNormalized=Cleadon',
#  'LocationNormalized=Cleator',
#  'LocationNormalized=Cleckheaton',
#  'LocationNormalized=Clerkenwell',
#  'LocationNormalized=Clevedon',
#  'LocationNormalized=Cleveley',
#  'LocationNormalized=Cliddesden',
#  'LocationNormalized=Clifton',
#  'LocationNormalized=Cliftonville',
#  'LocationNormalized=Clitheroe',
#  'LocationNormalized=Clydebank',
#  'LocationNormalized=Coaley',
#  'LocationNormalized=Coalville',
#  'LocationNormalized=Coatbridge',
#  'LocationNormalized=Cobham',
#  'LocationNormalized=Cockermouth',
#  'LocationNormalized=Cockfosters',
#  'LocationNormalized=Colchester',
#  'LocationNormalized=Coleford',
#  'LocationNormalized=Coleraine',
#  'LocationNormalized=Coleshill',
#  'LocationNormalized=Colindale',
#  'LocationNormalized=Collyhurst',
#  'LocationNormalized=Colnbrook',
#  'LocationNormalized=Colne',
#  'LocationNormalized=Colwyn Bay',
#  'LocationNormalized=Congleton',
#  'LocationNormalized=Coniston',
#  'LocationNormalized=Coniston Cold',
#  'LocationNormalized=Consett',
#  'LocationNormalized=Conwy',
#  'LocationNormalized=Cookham Dean',
#  'LocationNormalized=Coolham',
#  'LocationNormalized=Corbridge',
#  'LocationNormalized=Corby',
#  'LocationNormalized=Cornwall',
#  'LocationNormalized=Cornwell',
#  'LocationNormalized=Corsham',
#  'LocationNormalized=Coscote',
#  'LocationNormalized=Cosford',
#  'LocationNormalized=Cosham',
#  'LocationNormalized=Cottingham',
#  'LocationNormalized=Coulsdon',
#  'LocationNormalized=Covent Garden',
#  'LocationNormalized=Coventry',
#  'LocationNormalized=Cowbridge',
#  'LocationNormalized=Cowdenbeath',
#  'LocationNormalized=Cowes',
#  'LocationNormalized=Cradley Heath',
#  'LocationNormalized=Craigavon',
#  'LocationNormalized=Craigiehall',
#  'LocationNormalized=Cramlington',
#  'LocationNormalized=Cranbrook',
#  'LocationNormalized=Cranfield',
#  'LocationNormalized=Cranleigh',
#  'LocationNormalized=Craven Arms',
#  'LocationNormalized=Crawley',
#  'LocationNormalized=Crayford',
#  'LocationNormalized=Crediton',
#  'LocationNormalized=Cressington',
#  'LocationNormalized=Creswell',
#  'LocationNormalized=Crewe',
#  'LocationNormalized=Crewkerne',
#  'LocationNormalized=Crianlarich',
#  'LocationNormalized=Crick',
#  'LocationNormalized=Cricklewood',
#  'LocationNormalized=Crieff',
#  'LocationNormalized=Criftins',
#  'LocationNormalized=Cromer',
#  'LocationNormalized=Cronton',
#  'LocationNormalized=Crowborough',
#  'LocationNormalized=Crowthorne',
#  'LocationNormalized=Croxley Green',
#  'LocationNormalized=Croydon',
#  'LocationNormalized=Crymych',
#  'LocationNormalized=Cuffley',
#  'LocationNormalized=Cullompton',
#  'LocationNormalized=Culmhead',
#  'LocationNormalized=Cumbria',
#  'LocationNormalized=Cumnock',
#  'LocationNormalized=Cupar',
#  'LocationNormalized=Cutmill',
#  'LocationNormalized=Cwmbran',
#  'LocationNormalized=Dagenham',
#  'LocationNormalized=Dalgety Bay',
#  'LocationNormalized=Dalkeith',
#  'LocationNormalized=Dallas',
#  'LocationNormalized=Dalry',
#  'LocationNormalized=Daresbury',
#  'LocationNormalized=Darlington',
#  'LocationNormalized=Dartford',
#  'LocationNormalized=Dartmouth',
#  'LocationNormalized=Darwen',
#  'LocationNormalized=Datchet',
#  'LocationNormalized=Daventry',
#  'LocationNormalized=Dawlish',
#  'LocationNormalized=Deal',
#  'LocationNormalized=Dean Clough Industrial Park',
#  'LocationNormalized=Deane',
#  'LocationNormalized=Deeside',
#  'LocationNormalized=Denbighshire',
#  'LocationNormalized=Denmark Hill',
#  'LocationNormalized=Dentons Green',
#  'LocationNormalized=Derby',
#  'LocationNormalized=Derbyshire',
#  'LocationNormalized=Dereham',
#  'LocationNormalized=Derry',
#  'LocationNormalized=Desborough',
#  'LocationNormalized=Desford',
#  'LocationNormalized=Devizes',
#  'LocationNormalized=Devon',
#  'LocationNormalized=Dewsbury',
#  'LocationNormalized=Didcot',
#  'LocationNormalized=Dinton',
#  'LocationNormalized=Diss',
#  'LocationNormalized=Ditchingham',
#  'LocationNormalized=Docklands',
#  'LocationNormalized=Donaghadee',
#  'LocationNormalized=Doncaster',
#  'LocationNormalized=Dorchester',
#  'LocationNormalized=Dorking',
#  'LocationNormalized=Dorset',
#  'LocationNormalized=Dover',
#  'LocationNormalized=Downes',
#  'LocationNormalized=Downham Market',
#  'LocationNormalized=Downpatrick',
#  'LocationNormalized=Drayton',
#  'LocationNormalized=Droitwich',
#  'LocationNormalized=Dronfield',
#  'LocationNormalized=Dudley',
#  'LocationNormalized=Dukinfield',
#  'LocationNormalized=Dulwich',
#  'LocationNormalized=Dumbarton',
#  'LocationNormalized=Dumfries',
#  'LocationNormalized=Dumfries & Galloway',
#  'LocationNormalized=Dunbar',
#  'LocationNormalized=Dunblane',
#  'LocationNormalized=Dundee',
#  'LocationNormalized=Dunfermline',
#  'LocationNormalized=Dungannon',
#  'LocationNormalized=Dungeness',
#  'LocationNormalized=Dunham-On-Trent',
#  'LocationNormalized=Dunmow',
#  'LocationNormalized=Dunoon',
#  'LocationNormalized=Dunstable',
#  'LocationNormalized=Dunwich',
#  'LocationNormalized=Durham',
#  'LocationNormalized=Durham Tees Valley Airport',
#  'LocationNormalized=Dursley',
#  'LocationNormalized=Ealing',
#  'LocationNormalized=Earls Colne',
#  'LocationNormalized=East Anton',
#  'LocationNormalized=East Ayrshire',
#  'LocationNormalized=East End Green',
#  'LocationNormalized=East Goscote',
#  'LocationNormalized=East Grinstead',
#  'LocationNormalized=East Hanningfield',
#  'LocationNormalized=East Harptree',
#  'LocationNormalized=East Holton',
#  'LocationNormalized=East Kilbride',
#  'LocationNormalized=East Leake',
#  'LocationNormalized=East London',
#  'LocationNormalized=East Lothian',
#  'LocationNormalized=East Midlands',
#  'LocationNormalized=East Molesey',
#  'LocationNormalized=East Riding',
#  'LocationNormalized=East Sheen',
#  'LocationNormalized=East Sussex',
#  'LocationNormalized=East Tuddenham',
#  'LocationNormalized=East Wall',
#  'LocationNormalized=East Wittering',
#  'LocationNormalized=Eastbourne',
#  'LocationNormalized=Eastern England',
#  'LocationNormalized=Eastleigh',
#  'LocationNormalized=Eaton Socon',
#  'LocationNormalized=Ebbw Vale',
#  'LocationNormalized=Eccles',
#  'LocationNormalized=Edenbridge',
#  'LocationNormalized=Edgbaston',
#  'LocationNormalized=Edge',
#  'LocationNormalized=Edgware',
#  'LocationNormalized=Edinburgh',
#  'LocationNormalized=Edinburgh Technopole',
#  'LocationNormalized=Edmonton',
#  'LocationNormalized=Edwalton',
#  'LocationNormalized=Egham',
#  'LocationNormalized=Egremont',
#  'LocationNormalized=Egypt',
#  'LocationNormalized=Elgin',
#  'LocationNormalized=Elland',
#  'LocationNormalized=Ellesmere',
#  'LocationNormalized=Ellesmere Port',
#  'LocationNormalized=Ellon',
#  'LocationNormalized=Elmbridge',
#  'LocationNormalized=Elstow',
#  'LocationNormalized=Eltham',
#  'LocationNormalized=Ely',
#  'LocationNormalized=Emsworth',
#  'LocationNormalized=Enfield',
#  'LocationNormalized=Englefield',
#  'LocationNormalized=Enniskillen',
#  'LocationNormalized=Enstone',
#  'LocationNormalized=Epping',
#  'LocationNormalized=Epsom',
#  'LocationNormalized=Erdington',
#  'LocationNormalized=Erith',
#  'LocationNormalized=Erskine',
#  'LocationNormalized=Esher',
#  'LocationNormalized=Essex',
#  'LocationNormalized=Evesham',
#  'LocationNormalized=Ewell',
#  'LocationNormalized=Exeter',
#  'LocationNormalized=Exeter Airport',
#  'LocationNormalized=Exmouth',
#  'LocationNormalized=Eye',
#  'LocationNormalized=Eynsham',
#  'LocationNormalized=Fakenham',
#  'LocationNormalized=Falkirk',
#  'LocationNormalized=Falmer',
#  'LocationNormalized=Falmouth',
#  'LocationNormalized=Far Arnside',
#  'LocationNormalized=Fareham',
#  'LocationNormalized=Faringdon',
#  'LocationNormalized=Farmoor',
#  'LocationNormalized=Farnborough',
#  'LocationNormalized=Farnham',
#  'LocationNormalized=Farringdon',
#  'LocationNormalized=Faversham',
#  'LocationNormalized=Faygate',
#  'LocationNormalized=Felixstowe',
#  'LocationNormalized=Feltham',
#  'LocationNormalized=Ferndown',
#  'LocationNormalized=Fife',
#  'LocationNormalized=Filey',
#  'LocationNormalized=Filton',
#  'LocationNormalized=Finchley',
#  'LocationNormalized=Firgrove',
#  'LocationNormalized=Fitzrovia',
#  'LocationNormalized=Flackwell Heath',
#  'LocationNormalized=Fleet',
#  'LocationNormalized=Fleet Street',
#  'LocationNormalized=Fleetwood',
#  'LocationNormalized=Flint',
#  'LocationNormalized=Flintshire',
#  'LocationNormalized=Folkestone',
#  'LocationNormalized=Ford',
#  'LocationNormalized=Ford Bridge',
#  'LocationNormalized=Fordingbridge',
#  'LocationNormalized=Forest Beck',
#  'LocationNormalized=Forest Row',
#  'LocationNormalized=Forfar',
#  'LocationNormalized=Forres',
#  'LocationNormalized=Fort William',
#  'LocationNormalized=Foston',
#  'LocationNormalized=Fradley Park',
#  'LocationNormalized=Fraserburgh',
#  'LocationNormalized=Friern Barnet',
#  'LocationNormalized=Frimley',
#  'LocationNormalized=Frodsham',
#  'LocationNormalized=Frome',
#  'LocationNormalized=Fulford',
#  'LocationNormalized=Fulham',
#  'LocationNormalized=Furness Vale',
#  'LocationNormalized=Gainsborough',
#  'LocationNormalized=Galashiels',
#  'LocationNormalized=Gargrave',
#  'LocationNormalized=Garstang',
#  'LocationNormalized=Gateshead',
#  'LocationNormalized=Gatwick',
#  'LocationNormalized=Gaydon',
#  'LocationNormalized=Gerrards Cross',
#  'LocationNormalized=Gibraltar',
#  'LocationNormalized=Gillingham',
#  'LocationNormalized=Gipsy Hill',
#  'LocationNormalized=Girvan',
#  'LocationNormalized=Glanton',
#  'LocationNormalized=Glasgow',
#  'LocationNormalized=Glasgow Airport',
#  'LocationNormalized=Glasgow East Investment Park',
#  'LocationNormalized=Glastonbury',
#  'LocationNormalized=Glemsford',
#  'LocationNormalized=Glenrothes',
#  'LocationNormalized=Glossop',
#  'LocationNormalized=Gloucester',
#  'LocationNormalized=Gloucestershire',
#  'LocationNormalized=Godalming',
#  'LocationNormalized=Godstone',
#  'LocationNormalized=Gonerby Hill Foot',
#  'LocationNormalized=Goole',
#  'LocationNormalized=Goring-By-Sea',
#  'LocationNormalized=Gorleston',
#  'LocationNormalized=Gorton',
#  'LocationNormalized=Gosport',
#  'LocationNormalized=Grange-Over-Sands',
#  'LocationNormalized=Grangemouth',
#  'LocationNormalized=Grantham',
#  'LocationNormalized=Gravesend',
#  'LocationNormalized=Grays',
#  'LocationNormalized=Greasbrough',
#  'LocationNormalized=Great Barr',
#  'LocationNormalized=Great Bridge',
#  'LocationNormalized=Great Canfield',
#  'LocationNormalized=Great Kelk',
#  'LocationNormalized=Great Langdale',
#  'LocationNormalized=Great Missenden',
#  'LocationNormalized=Great Warley',
#  'LocationNormalized=Great Yarmouth',
#  'LocationNormalized=Greater Manchester',
#  'LocationNormalized=Greenford',
#  'LocationNormalized=Greenhithe',
#  'LocationNormalized=Greenock',
#  'LocationNormalized=Greenwich',
#  'LocationNormalized=Grimethorpe',
#  'LocationNormalized=Grimsby',
#  'LocationNormalized=Gronant',
#  'LocationNormalized=Guernsey',
#  'LocationNormalized=Guildford',
#  'LocationNormalized=Guisborough',
#  'LocationNormalized=Guiseley',
#  'LocationNormalized=H M Naval Base',
#  'LocationNormalized=Hackney',
#  'LocationNormalized=Haddington',
#  'LocationNormalized=Hadleigh',
#  'LocationNormalized=Hailsham',
#  'LocationNormalized=Halesowen',
#  'LocationNormalized=Halesworth',
#  'LocationNormalized=Halewood',
#  'LocationNormalized=Halifax',
#  'LocationNormalized=Halstead',
#  'LocationNormalized=Hamilton',
#  'LocationNormalized=Hammersmith',
#  'LocationNormalized=Hampshire',
#  'LocationNormalized=Hampstead',
#  'LocationNormalized=Hampton',
#  'LocationNormalized=Hampton Poyle',
#  'LocationNormalized=Hamworthy',
#  'LocationNormalized=Handbridge',
#  'LocationNormalized=Hanham',
#  'LocationNormalized=Hanley',
#  'LocationNormalized=Hanwell',
#  'LocationNormalized=Harefield',
#  'LocationNormalized=Harlow',
#  'LocationNormalized=Harpenden',
#  'LocationNormalized=Harrogate',
#  'LocationNormalized=Harrow',
#  'LocationNormalized=Hartlepool',
#  'LocationNormalized=Harwell',
#  'LocationNormalized=Harwich',
#  'LocationNormalized=Haslemere',
#  'LocationNormalized=Hassocks',
#  'LocationNormalized=Hastings',
#  'LocationNormalized=Hatfield',
#  'LocationNormalized=Havant',
#  'LocationNormalized=Haverfordwest',
#  'LocationNormalized=Haverhill',
#  'LocationNormalized=Havering-Atte-Bower',
#  'LocationNormalized=Hawarden',
#  'LocationNormalized=Haye',
#  'LocationNormalized=Hayes',
#  'LocationNormalized=Hayle',
#  'LocationNormalized=Hayling Island',
#  'LocationNormalized=Haywards Heath',
#  'LocationNormalized=Healey',
#  'LocationNormalized=Heanor',
#  'LocationNormalized=Heath',
#  'LocationNormalized=Heathfield',
#  'LocationNormalized=Heathrow',
#  'LocationNormalized=Heathrow Airport',
#  'LocationNormalized=Hebburn',
#  'LocationNormalized=Heckington',
#  'LocationNormalized=Heckmondwike',
#  'LocationNormalized=Helensburgh',
#  'LocationNormalized=Helston',
#  'LocationNormalized=Hemel Hempstead',
#  'LocationNormalized=Henfield',
#  'LocationNormalized=Hengoed',
#  'LocationNormalized=Henley-In-Arden',
#  'LocationNormalized=Henley-On-Thames',
#  'LocationNormalized=Henlow',
#  'LocationNormalized=Hereford',
#  'LocationNormalized=Herefordshire',
#  'LocationNormalized=Hermitage',
#  'LocationNormalized=Herne Bay',
#  'LocationNormalized=Hertford',
#  'LocationNormalized=Hertford Heath',
#  'LocationNormalized=Hertfordshire',
#  'LocationNormalized=Hessle',
#  'LocationNormalized=Hest Bank',
#  'LocationNormalized=Hexham',
#  'LocationNormalized=Heywood',
#  'LocationNormalized=High Wycombe',
#  'LocationNormalized=Highbridge',
#  'LocationNormalized=Highlands',
#  'LocationNormalized=Hildenborough',
#  'LocationNormalized=Hillingdon',
#  'LocationNormalized=Hinckley',
#  'LocationNormalized=Hinderwell',
#  'LocationNormalized=Hindhead',
#  'LocationNormalized=Histon',
#  'LocationNormalized=Hitchin',
#  'LocationNormalized=Hockley',
#  'LocationNormalized=Hoddesdon',
#  'LocationNormalized=Holland Park',
#  'LocationNormalized=Holloway',
#  'LocationNormalized=Holmer',
#  'LocationNormalized=Holmfirth',
#  'LocationNormalized=Holsworthy',
#  'LocationNormalized=Holywell',
#  'LocationNormalized=Holywood',
#  'LocationNormalized=Honiton',
#  'LocationNormalized=Hook',
#  'LocationNormalized=Hooke',
#  'LocationNormalized=Hope',
#  'LocationNormalized=Hope Carr',
#  'LocationNormalized=Horbury',
#  'LocationNormalized=Horley',
#  'LocationNormalized=Horncastle',
#  'LocationNormalized=Hornchurch',
#  'LocationNormalized=Horsforth',
#  'LocationNormalized=Horsham',
#  'LocationNormalized=Hotwells',
#  'LocationNormalized=Houghton Le Spring',
#  'LocationNormalized=Houghton Regis',
#  'LocationNormalized=Hounslow',
#  'LocationNormalized=Houston',
#  'LocationNormalized=Hove',
#  'LocationNormalized=Hoveton',
#  'LocationNormalized=Hucknall',
#  'LocationNormalized=Huddersfield',
#  'LocationNormalized=Hull',
#  'LocationNormalized=Humber',
#  'LocationNormalized=Hungerford',
#  'LocationNormalized=Hunstanton',
#  'LocationNormalized=Huntingdon',
#  'LocationNormalized=Huntly',
#  'LocationNormalized=Huyton',
#  'LocationNormalized=Hyde',
#  'LocationNormalized=Hyde Park',
#  'LocationNormalized=Ilford',
#  'LocationNormalized=Ilkeston',
#  'LocationNormalized=Ilkley',
#  'LocationNormalized=Ilminster',
#  'LocationNormalized=Immingham',
#  'LocationNormalized=Invergordon',
#  'LocationNormalized=Inverkeithing',
#  'LocationNormalized=Inverness',
#  'LocationNormalized=Inverurie',
#  'LocationNormalized=Ipswich',
#  'LocationNormalized=Ireland',
#  'LocationNormalized=Irlam',
#  "LocationNormalized=Irlams O' Th' Height",
#  'LocationNormalized=Irthlingborough',
#  'LocationNormalized=Irvine',
#  'LocationNormalized=Isle Of Anglesey',
#  'LocationNormalized=Isle Of Arran',
#  'LocationNormalized=Isle Of Bute',
#  'LocationNormalized=Isle Of Harris',
#  'LocationNormalized=Isle Of Lewis',
#  'LocationNormalized=Isle Of Man',
#  'LocationNormalized=Isle Of North Uist',
#  'LocationNormalized=Isle Of Wight',
#  'LocationNormalized=Isles Of Scilly',
#  'LocationNormalized=Isleworth',
#  'LocationNormalized=Islington',
#  'LocationNormalized=Iver',
#  'LocationNormalized=Ivybridge',
#  'LocationNormalized=Jarrow',
#  'LocationNormalized=Jersey',
#  'LocationNormalized=Keele',
#  'LocationNormalized=Keighley',
#  'LocationNormalized=Kelso',
#  'LocationNormalized=Kempston',
#  'LocationNormalized=Kendal',
#  'LocationNormalized=Kenilworth',
#  'LocationNormalized=Kennoway',
#  'LocationNormalized=Kensington',
#  'LocationNormalized=Kent',
#  'LocationNormalized=Kentish Town',
#  'LocationNormalized=Keswick',
#  'LocationNormalized=Kettering',
#  'LocationNormalized=Keynsham',
#  'LocationNormalized=Kidbrooke',
#  'LocationNormalized=Kidderminster',
#  'LocationNormalized=Kidlington',
#  'LocationNormalized=Kilmarnock',
#  'LocationNormalized=Kilmuir',
#  "LocationNormalized=King's Lynn",
#  'LocationNormalized=Kingfisher Shopping Centre',
#  'LocationNormalized=Kings Hill',
#  'LocationNormalized=Kings Langley',
#  'LocationNormalized=Kings Norton',
#  'LocationNormalized=Kingsbarns',
#  'LocationNormalized=Kingsbridge',
#  'LocationNormalized=Kingston Upon Thames',
#  'LocationNormalized=Kingston Vale',
#  'LocationNormalized=Kingswood',
#  'LocationNormalized=Kingussie',
#  'LocationNormalized=Kinross',
#  'LocationNormalized=Kirkby',
#  'LocationNormalized=Kirkby-In-Ashfield',
#  'LocationNormalized=Kirkcaldy',
#  'LocationNormalized=Kirkham',
#  'LocationNormalized=Kirkhamgate',
#  'LocationNormalized=Kirknewton',
#  'LocationNormalized=Kirkwall',
#  'LocationNormalized=Knaresborough',
#  'LocationNormalized=Knebworth',
#  'LocationNormalized=Knottingley',
#  'LocationNormalized=Knowsley',
#  'LocationNormalized=Knutsford',
#  'LocationNormalized=Laindon',
#  'LocationNormalized=Lakenheath',
#  'LocationNormalized=Lambeth',
#  'LocationNormalized=Lampeter',
#  'LocationNormalized=Lanark',
#  'LocationNormalized=Lancashire',
#  'LocationNormalized=Lancaster',
#  'LocationNormalized=Lancing',
#  'LocationNormalized=Langley',
#  'LocationNormalized=Langport',
#  'LocationNormalized=Largs',
#  'LocationNormalized=Lathom',
#  'LocationNormalized=Lauder',
#  'LocationNormalized=Launceston',
#  'LocationNormalized=Lea Bridge',
#  'LocationNormalized=Leamington Spa',
#  'LocationNormalized=Leamouth',
#  'LocationNormalized=Leatherhead',
#  'LocationNormalized=Leavesden',
#  'LocationNormalized=Lechlade',
#  'LocationNormalized=Leconfield',
#  'LocationNormalized=Ledbury',
#  'LocationNormalized=Lee-On-The-Solent',
#  'LocationNormalized=Leeds',
#  'LocationNormalized=Leek',
#  'LocationNormalized=Leicester',
#  'LocationNormalized=Leicestershire',
#  'LocationNormalized=Leigh',
#  'LocationNormalized=Leigh-On-Sea',
#  'LocationNormalized=Leighton Buzzard',
#  'LocationNormalized=Leiston',
#  'LocationNormalized=Leominster',
#  'LocationNormalized=Lesnes Woods',
#  'LocationNormalized=Letchworth Garden City',
#  'LocationNormalized=Leven',
#  'LocationNormalized=Lewes',
#  'LocationNormalized=Lewisham',
#  'LocationNormalized=Leyburn',
#  'LocationNormalized=Leyland',
#  'LocationNormalized=Leyton',
#  'LocationNormalized=Lichfield',
#  'LocationNormalized=Lightwater',
#  'LocationNormalized=Lincoln',
#  'LocationNormalized=Lincolnshire',
#  'LocationNormalized=Lindrick Common',
#  'LocationNormalized=Lingfield',
#  'LocationNormalized=Linlithgow',
#  'LocationNormalized=Linlithgow Bridge',
#  'LocationNormalized=Liphook',
#  'LocationNormalized=Lisburn',
#  'LocationNormalized=Liskeard',
#  'LocationNormalized=Liss',
#  'LocationNormalized=Litherland',
#  'LocationNormalized=Little Bromley',
#  'LocationNormalized=Little Chesterford',
#  'LocationNormalized=Little Ellingham',
#  'LocationNormalized=Little London',
#  'LocationNormalized=Little Marlow',
#  'LocationNormalized=Littleborough',
#  'LocationNormalized=Littleham',
#  'LocationNormalized=Littlehampton',
#  'LocationNormalized=Liverpool',
#  'LocationNormalized=Liversedge',
#  'LocationNormalized=Livingston',
#  'LocationNormalized=Llanbedr Dyffryn Clwyd',
#  'LocationNormalized=Llanberis',
#  'LocationNormalized=Llandaff North',
#  'LocationNormalized=Llandinam',
#  'LocationNormalized=Llandrindod Wells',
#  'LocationNormalized=Llandudno',
#  'LocationNormalized=Llanelli',
#  'LocationNormalized=Llanfairpwllgwyngyll',
#  'LocationNormalized=Llangefni',
#  'LocationNormalized=Llangennech',
#  'LocationNormalized=Llangollen',
#  'LocationNormalized=Llanrug',
#  'LocationNormalized=Llantrisant',
#  'LocationNormalized=Llanwrda',
#  'LocationNormalized=Llanwrtyd Wells',
#  'LocationNormalized=Lochgelly',
#  'LocationNormalized=Lochgilphead',
#  'LocationNormalized=London',
#  'LocationNormalized=London Colney',
#  'LocationNormalized=London Stansted Airport',
#  'LocationNormalized=Londonderry',
#  'LocationNormalized=Long Sutton',
#  'LocationNormalized=Longbenton',
#  'LocationNormalized=Longbridge',
#  'LocationNormalized=Longfield',
#  'LocationNormalized=Longtown',
#  'LocationNormalized=Lostwithiel',
#  'LocationNormalized=Loudwater',
#  'LocationNormalized=Loughborough',
#  'LocationNormalized=Loughton',
#  'LocationNormalized=Lount',
#  'LocationNormalized=Louth',
#  'LocationNormalized=Lowestoft',
#  'LocationNormalized=Ludlow',
#  'LocationNormalized=Luton',
#  'LocationNormalized=Lutterworth',
#  'LocationNormalized=Lydbury North',
#  'LocationNormalized=Lydney',
#  'LocationNormalized=Lyme Regis',
#  'LocationNormalized=Lymington',
#  'LocationNormalized=Lymm',
#  'LocationNormalized=Lympstone',
#  'LocationNormalized=Lyndhurst',
#  'LocationNormalized=Lyne',
#  'LocationNormalized=Lynmouth',
#  'LocationNormalized=Lytham',
#  'LocationNormalized=Macclesfield',
#  'LocationNormalized=Machynlleth',
#  'LocationNormalized=Maesteg',
#  'LocationNormalized=Maida Vale',
#  'LocationNormalized=Maidenhead',
#  'LocationNormalized=Maidstone',
#  'LocationNormalized=Maldon',
#  'LocationNormalized=Malmesbury',
#  'LocationNormalized=Malpas',
#  'LocationNormalized=Malton',
#  'LocationNormalized=Malvern',
#  'LocationNormalized=Manchester',
#  'LocationNormalized=Manchester Science Park',
#  'LocationNormalized=Manningtree',
#  ...]

# %%
data_new_train.shape
# Out:
# (60000, 24627)

# %% [markdown]
# **3.  Обучите гребневую регрессию с параметрами alpha=1 и random_state=241. Целевая переменная записана в столбце SalaryNormalized.**

# %%
clf = Ridge(alpha=1, random_state=241)

# %%
clf.fit(X=data_new_train, y=train['SalaryNormalized'])
# Out:
# Ridge(alpha=1, random_state=241)

# %% [markdown]
# **4. Постройте прогнозы для двух примеров из файла salary-test-mini.csv. Значения полученных прогнозов являются ответом на задание. Укажите их через пробел.**

# %%
X_test_description = tf_idf.transform(test['FullDescription'])
X_test_features = enc.transform(test[['LocationNormalized', 'ContractTime']].to_dict('records'))
data_new_test = hstack([X_test_features, X_test_description])

# %%
test['SalaryNormalized'] = clf.predict(data_new_test)

# %%
test['SalaryNormalized'][0], test['SalaryNormalized'][1]
# Out:
# (56569.22991429722, 37138.92880941285)

# %%
with open('./1.txt', 'w') as f:
    f.write("56555.62 37188.32")
f.close()
